# %%
import numpy as np


import pandas as pd
import statsmodels.formula.api as smf
pd.set_option('display.max_columns', 500)
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.graphics as sgr
from statsmodels.formula.api import logit
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %matplotlib inline
import tweepy

from twitter_config import config



df=pd.read_csv('desktop/retweets.csv')
dfnew=df.loc[(df['lang']=='en')]
auth = tweepy.OAuthHandler(config['consumer_key'], config['consumer_secret'])
auth.set_access_token(config['access_token'], config['access_token_secret'])

api = tweepy.API(auth, wait_on_rate_limit=True)


dfnew.head(5)
# Out:
#     origUserId origUserScreenName  origMepId    origMepName  origMepGroupId  \
# 3     19017675       Nigel_Farage       4525   Nigel FARAGE               6
# 5     17675072       MartinSchulz       1911  Martin SCHULZ               1
# 11    17675072       MartinSchulz       1911  Martin SCHULZ               1
# 12   744743599           Tim_Aker      99650       Tim AKER               6
# 13   744743599           Tim_Aker      99650       Tim AKER               6
#
#    origMepGroupShort  origMepCountryId origMepCountryShort  retweetUserId  \
# 3               EFDD                27                 GBR      121171051
# 5                S&D                10                 DEU     1668992125
# 11               S&D                10                 DEU       21648649
# 12              EFDD                27                 GBR      121171051
# 13              EFDD                27                 GBR       19017675
#
#    retweetUserScreenName  retweetMepId  retweetMepName  retweetMepGroupId  \
# 3         MargotLJParker        124945   Margot PARKER                  6
# 5          NathanGillMEP        124965     Nathan GILL                  6
# 11         maritaulvskog         96672  Marita ULVSKOG                  1
# 12        MargotLJParker        124945   Margot PARKER                  6
# 13          Nigel_Farage          4525    Nigel FARAGE                  6
#
#    retweetMepGroupShort  retweetMepCountryId retweetMepCountryShort  \
# 3                  EFDD                   27                    GBR
# 5                  EFDD                   27                    GBR
# 11                  S&D                   26                    SWE
# 12                 EFDD                   27                    GBR
# 13                 EFDD                   27                    GBR
#
#                      origCreatedAt         origTweetId  \
# 3   Wed Jul 04 11:05:03 +0000 2012  220473289259233285
# 5   Fri Jul 05 08:00:23 +0000 2013  353060776707235841
# 11  Sat May 17 12:47:17 +0000 2014  467647542378123264
# 12  Wed May 28 16:47:44 +0000 2014  471694322472353793
# 13  Wed May 28 16:47:44 +0000 2014  471694322472353793
#
#                   retweetCreatedAt      retweetTweetId lang
# 3   Sun Dec 07 21:46:00 +0000 2014  541710240014942209   en
# 5   Thu Jun 18 08:52:51 +0000 2015  611456527409524736   en
# 11  Wed Sep 16 09:15:06 +0000 2015  644077036022165504   en
# 12  Thu Dec 04 22:21:10 +0000 2014  540631925145493504   en
# 13  Sun Mar 29 18:53:32 +0000 2015  582254277122473984   en

# %%
#it takes a lot of time to download all the tweets

exc=0
list_of_ids=[]
# Fetch tweets from the twitter API using the following loop:
list_of_tweets = []
# Tweets that can't be found are saved in the list below:
cant_find_tweets_for_those_ids = []
for each_id in dfnew.origTweetId:   
    try:
        tweet = api.get_status(each_id)
        list_of_tweets.append(tweet.text)
        list_of_ids.append(each_id)
    except Exception as e:
        exc=exc+1
print(len(list_of_tweets))
print(exc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-469e1f06894e> in <module>
#       9 for each_id in dfnew.origTweetId:
#      10     try:
# ---> 11         tweet = api.get_status(each_id)
#      12         list_of_tweets.append(tweet.text)
#      13         list_of_ids.append(each_id)
#
# ~\Anaconda3\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# ~\Anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     187                                                 timeout=self.api.timeout,
#     188                                                 auth=auth,
# --> 189                                                 proxies=self.api.proxy)
#     190                 except Exception as e:
#     191                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in select_wait_for_socket(sock, read, write, timeout)
#      81     # thing.)
#      82     fn = partial(select.select, rcheck, wcheck, wcheck)
# ---> 83     rready, wready, xready = _retry_on_intr(fn, timeout)
#      84     return bool(rready or wready or xready)
#      85
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# KeyboardInterrupt:

# %%
percentile_list1 = pd.DataFrame(
    {'ids': list_of_ids})
percentile_list1=percentile_list1

percentile_list1.to_pickle('Desktop/dummy1.pkl') #saving the ids dataframe to a file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-5f000664a24e> in <module>
#       1 percentile_list1 = pd.DataFrame(
# ----> 2     {'ids': list_of_ids})
#       3 percentile_list1=percentile_list1
#       4
#       5 percentile_list1.to_pickle('Desktop/dummy1.pkl') #saving the ids dataframe to a file
#
# NameError: name 'list_of_ids' is not defined

# %%
percentile_list = pd.DataFrame(
    {'texts': list_of_tweets})
percentile_list=percentile_list

percentile_list.to_pickle('Desktop/dummy.pkl')#saving the texts dataframe to a file


percentile_list
# Out:
#       contributors  coordinates          created_at  \
# 0              NaN          NaN 2009-07-04 18:40:34
# 1              NaN          NaN 2009-06-14 14:37:22
# 2              NaN          NaN 2008-06-04 11:17:18
# 3              NaN          NaN 2008-07-11 20:41:57
# 4              NaN          NaN 2009-02-27 02:03:56
# 5              NaN          NaN 2009-06-26 23:36:29
# 6              NaN          NaN 2007-05-08 12:03:24
# 7              NaN          NaN 2007-07-11 06:17:16
# 8              NaN          NaN 2009-06-22 14:57:04
# 9              NaN          NaN 2008-06-16 02:51:26
# 10             NaN          NaN 2009-07-04 18:40:34
# 11             NaN          NaN 2007-04-13 06:21:11
# 12             NaN          NaN 2008-06-04 11:17:18
# 13             NaN          NaN 2008-07-11 20:41:57
# 14             NaN          NaN 2007-05-31 19:26:51
# 15             NaN          NaN 2008-09-08 20:46:52
# 16             NaN          NaN 2009-05-01 13:29:11
# 17             NaN          NaN 2009-07-04 18:40:34
# 18             NaN          NaN 2007-04-13 06:21:11
# 19             NaN          NaN 2008-05-26 01:06:32
# 20             NaN          NaN 2008-07-11 20:41:57
# 21             NaN          NaN 2009-05-21 13:26:57
# 22             NaN          NaN 2008-08-13 15:40:03
# 23             NaN          NaN 2007-05-31 19:26:51
# 24             NaN          NaN 2009-05-01 13:29:11
# 25             NaN          NaN 2009-04-09 19:16:32
# 26             NaN          NaN 2009-03-19 14:32:12
# 27             NaN          NaN 2007-08-26 17:53:45
# 28             NaN          NaN 2009-07-04 18:40:34
# 29             NaN          NaN 2008-05-26 01:06:32
# ...            ...          ...                 ...
# 1134           NaN          NaN 2007-08-26 17:53:45
# 1135           NaN          NaN 2008-07-23 16:00:44
# 1136           NaN          NaN 2009-07-04 18:40:34
# 1137           NaN          NaN 2009-06-30 01:50:15
# 1138           NaN          NaN 2009-06-19 15:55:11
# 1139           NaN          NaN 2008-07-11 20:41:57
# 1140           NaN          NaN 2009-08-15 02:41:31
# 1141           NaN          NaN 2007-05-31 19:26:51
# 1142           NaN          NaN 2008-09-14 09:01:31
# 1143           NaN          NaN 2008-09-08 20:46:52
# 1144           NaN          NaN 2009-05-01 13:29:11
# 1145           NaN          NaN 2009-03-19 14:32:12
# 1146           NaN          NaN 2009-08-11 07:58:43
# 1147           NaN          NaN 2009-08-15 15:03:59
# 1148           NaN          NaN 2009-07-04 18:40:34
# 1149           NaN          NaN 2008-07-11 20:41:57
# 1150           NaN          NaN 2009-04-01 00:37:45
# 1151           NaN          NaN 2009-08-15 02:41:31
# 1152           NaN          NaN 2009-07-03 02:41:05
# 1153           NaN          NaN 2009-06-26 23:36:29
# 1154           NaN          NaN 2007-05-31 19:26:51
# 1155           NaN          NaN 2009-02-02 18:15:24
# 1156           NaN          NaN 2009-08-11 07:58:43
# 1157           NaN          NaN 2009-07-04 18:40:34
# 1158           NaN          NaN 2008-05-26 01:06:32
# 1159           NaN          NaN 2009-06-19 15:55:11
# 1160           NaN          NaN 2008-07-11 20:41:57
# 1161           NaN          NaN 2007-05-31 19:26:51
# 1162           NaN          NaN 2009-07-23 17:27:19
# 1163           NaN          NaN 2009-04-09 19:16:32
#
#                                                entities  favorite_count  \
# 0     {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1     {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 2     {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 3     {'hashtags': [], 'symbols': [], 'user_mentions...               4
# 4     {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 5     {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 6     {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 7     {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 8     {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 9     {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 10    {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 11    {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 12    {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 13    {'hashtags': [], 'symbols': [], 'user_mentions...               4
# 14    {'hashtags': [], 'symbols': [], 'user_mentions...               3
# 15    {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 16    {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 17    {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 18    {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 19    {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 20    {'hashtags': [], 'symbols': [], 'user_mentions...               4
# 21    {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 22    {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 23    {'hashtags': [], 'symbols': [], 'user_mentions...               3
# 24    {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 25    {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 26    {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 27    {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 28    {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 29    {'hashtags': [], 'symbols': [], 'user_mentions...               0
# ...                                                 ...             ...
# 1134  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1135  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1136  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1137  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1138  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1139  {'hashtags': [], 'symbols': [], 'user_mentions...               4
# 1140  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1141  {'hashtags': [], 'symbols': [], 'user_mentions...               3
# 1142  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1143  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1144  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1145  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1146  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1147  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1148  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1149  {'hashtags': [], 'symbols': [], 'user_mentions...               4
# 1150  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1151  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1152  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1153  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1154  {'hashtags': [], 'symbols': [], 'user_mentions...               3
# 1155  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1156  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1157  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1158  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1159  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1160  {'hashtags': [], 'symbols': [], 'user_mentions...               4
# 1161  {'hashtags': [], 'symbols': [], 'user_mentions...               3
# 1162  {'hashtags': [], 'symbols': [], 'user_mentions...               0
# 1163  {'hashtags': [], 'symbols': [], 'user_mentions...               0
#
#       favorited  geo          id      id_str in_reply_to_screen_name  \
# 0         False  NaN  2472445567  2472445567                    None
# 1         False  NaN  2165445573  2165445573           jamierumbelow
# 2         False  NaN   826743260   826743260                    None
# 3         False  NaN   856010760   856010760                NobleRot
# 4         False  NaN  1256386124  1256386124                    None
# 5         False  NaN  2351820624  2351820624                    None
# 6         False  NaN    55031092    55031092                    None
# 7         False  NaN   144238332   144238332                    None
# 8         False  NaN  2279751087  2279751087                    None
# 9         False  NaN   835659450   835659450                    None
# 10        False  NaN  2472445567  2472445567                    None
# 11        False  NaN    26586771    26586771                    None
# 12        False  NaN   826743260   826743260                    None
# 13        False  NaN   856010760   856010760                NobleRot
# 14        False  NaN    85794542    85794542                    None
# 15        False  NaN   914281548   914281548                  kristy
# 16        False  NaN  1668992125  1668992125                    None
# 17        False  NaN  2472445567  2472445567                    None
# 18        False  NaN    26586771    26586771                    None
# 19        False  NaN   819843415   819843415                 srtalee
# 20        False  NaN   856010760   856010760                NobleRot
# 21        False  NaN  1870771148  1870771148                    None
# 22        False  NaN   886420428   886420428                    Sacc
# 23        False  NaN    85794542    85794542                    None
# 24        False  NaN  1668992125  1668992125                    None
# 25        False  NaN  1485429175  1485429175              Coverville
# 26        False  NaN  1354570123  1354570123                  kajeaw
# 27        False  NaN   228673882   228673882                    None
# 28        False  NaN  2472445567  2472445567                    None
# 29        False  NaN   819843415   819843415                 srtalee
# ...         ...  ...         ...         ...                     ...
# 1134      False  NaN   228673882   228673882                    None
# 1135      False  NaN   866252216   866252216                    None
# 1136      False  NaN  2472445567  2472445567                    None
# 1137      False  NaN  2397043430  2397043430                    None
# 1138      False  NaN  2239747586  2239747586                    None
# 1139      False  NaN   856010760   856010760                NobleRot
# 1140      False  NaN  3321185645  3321185645                smallbit
# 1141      False  NaN    85794542    85794542                    None
# 1142      False  NaN   920895180   920895180                    None
# 1143      False  NaN   914281548   914281548                  kristy
# 1144      False  NaN  1668992125  1668992125                    None
# 1145      False  NaN  1354570123  1354570123                  kajeaw
# 1146      False  NaN  3242161976  3242161976                    None
# 1147      False  NaN  3329053900  3329053900                    None
# 1148      False  NaN  2472445567  2472445567                    None
# 1149      False  NaN   856010760   856010760                NobleRot
# 1150      False  NaN  1428138349  1428138349                    None
# 1151      False  NaN  3321185645  3321185645                smallbit
# 1152      False  NaN  2447738125  2447738125               felpsvita
# 1153      False  NaN  2351820624  2351820624                    None
# 1154      False  NaN    85794542    85794542                    None
# 1155      False  NaN  1170514248  1170514248                    None
# 1156      False  NaN  3242161976  3242161976                    None
# 1157      False  NaN  2472445567  2472445567                    None
# 1158      False  NaN   819843415   819843415                 srtalee
# 1159      False  NaN  2239747586  2239747586                    None
# 1160      False  NaN   856010760   856010760                NobleRot
# 1161      False  NaN    85794542    85794542                    None
# 1162      False  NaN  2801885037  2801885037             Dark_Nubian
# 1163      False  NaN  1485429175  1485429175              Coverville
#
#       in_reply_to_status_id  in_reply_to_status_id_str  in_reply_to_user_id  \
# 0                       NaN                        NaN                  NaN
# 1              2.165420e+09               2.165420e+09           14316803.0
# 2                       NaN                        NaN                  NaN
# 3              8.560068e+08               8.560068e+08            6167072.0
# 4                       NaN                        NaN                  NaN
# 5                       NaN                        NaN                  NaN
# 6                       NaN                        NaN                  NaN
# 7                       NaN                        NaN                  NaN
# 8                       NaN                        NaN                  NaN
# 9                       NaN                        NaN                  NaN
# 10                      NaN                        NaN                  NaN
# 11                      NaN                        NaN                  NaN
# 12                      NaN                        NaN                  NaN
# 13             8.560068e+08               8.560068e+08            6167072.0
# 14                      NaN                        NaN                  NaN
# 15             9.142795e+08               9.142795e+08           14415152.0
# 16                      NaN                        NaN                  NaN
# 17                      NaN                        NaN                  NaN
# 18                      NaN                        NaN                  NaN
# 19             8.198421e+08               8.198421e+08            3962891.0
# 20             8.560068e+08               8.560068e+08            6167072.0
# 21                      NaN                        NaN                  NaN
# 22             8.863680e+08               8.863680e+08            6971102.0
# 23                      NaN                        NaN                  NaN
# 24                      NaN                        NaN                  NaN
# 25             1.485353e+09               1.485353e+09             776031.0
# 26             1.354531e+09               1.354531e+09           15243446.0
# 27                      NaN                        NaN                  NaN
# 28                      NaN                        NaN                  NaN
# 29             8.198421e+08               8.198421e+08            3962891.0
# ...                     ...                        ...                  ...
# 1134                    NaN                        NaN                  NaN
# 1135                    NaN                        NaN                  NaN
# 1136                    NaN                        NaN                  NaN
# 1137                    NaN                        NaN                  NaN
# 1138                    NaN                        NaN                  NaN
# 1139           8.560068e+08               8.560068e+08            6167072.0
# 1140           3.321170e+09               3.321170e+09           17557028.0
# 1141                    NaN                        NaN                  NaN
# 1142                    NaN                        NaN                  NaN
# 1143           9.142795e+08               9.142795e+08           14415152.0
# 1144                    NaN                        NaN                  NaN
# 1145           1.354531e+09               1.354531e+09           15243446.0
# 1146                    NaN                        NaN                  NaN
# 1147                    NaN                        NaN                  NaN
# 1148                    NaN                        NaN                  NaN
# 1149           8.560068e+08               8.560068e+08            6167072.0
# 1150                    NaN                        NaN                  NaN
# 1151           3.321170e+09               3.321170e+09           17557028.0
# 1152                    NaN                        NaN           53244424.0
# 1153                    NaN                        NaN                  NaN
# 1154                    NaN                        NaN                  NaN
# 1155                    NaN                        NaN                  NaN
# 1156                    NaN                        NaN                  NaN
# 1157                    NaN                        NaN                  NaN
# 1158           8.198421e+08               8.198421e+08            3962891.0
# 1159                    NaN                        NaN                  NaN
# 1160           8.560068e+08               8.560068e+08            6167072.0
# 1161                    NaN                        NaN                  NaN
# 1162           2.801178e+09               2.801178e+09           24693464.0
# 1163           1.485353e+09               1.485353e+09             776031.0
#
#       in_reply_to_user_id_str  is_quote_status lang  place  retweet_count  \
# 0                         NaN            False   en    NaN              0
# 1                  14316803.0            False   en    NaN              0
# 2                         NaN            False   ja    NaN              0
# 3                   6167072.0            False   en    NaN              2
# 4                         NaN            False   en    NaN              0
# 5                         NaN            False   en    NaN              0
# 6                         NaN            False   ja    NaN              0
# 7                         NaN            False   en    NaN              0
# 8                         NaN            False   en    NaN              0
# 9                         NaN            False   en    NaN              0
# 10                        NaN            False   en    NaN              0
# 11                        NaN            False   ja    NaN              0
# 12                        NaN            False   ja    NaN              0
# 13                  6167072.0            False   en    NaN              2
# 14                        NaN            False   en    NaN              2
# 15                 14415152.0            False   en    NaN              0
# 16                        NaN            False   uk    NaN              0
# 17                        NaN            False   en    NaN              0
# 18                        NaN            False   ja    NaN              0
# 19                  3962891.0            False   es    NaN              0
# 20                  6167072.0            False   en    NaN              2
# 21                        NaN            False   en    NaN              0
# 22                  6971102.0            False   en    NaN              0
# 23                        NaN            False   en    NaN              2
# 24                        NaN            False   uk    NaN              0
# 25                   776031.0            False   en    NaN              1
# 26                 15243446.0            False   th    NaN              0
# 27                        NaN            False   ja    NaN              0
# 28                        NaN            False   en    NaN              0
# 29                  3962891.0            False   es    NaN              0
# ...                       ...              ...  ...    ...            ...
# 1134                      NaN            False   ja    NaN              0
# 1135                      NaN            False   ja    NaN              0
# 1136                      NaN            False   en    NaN              0
# 1137                      NaN            False   en    NaN              0
# 1138                      NaN            False   es    NaN              0
# 1139                6167072.0            False   en    NaN              2
# 1140               17557028.0            False   en    NaN              0
# 1141                      NaN            False   en    NaN              2
# 1142                      NaN            False   en    NaN              0
# 1143               14415152.0            False   en    NaN              0
# 1144                      NaN            False   uk    NaN              0
# 1145               15243446.0            False   th    NaN              0
# 1146                      NaN            False   en    NaN              0
# 1147                      NaN            False   en    NaN              0
# 1148                      NaN            False   en    NaN              0
# 1149                6167072.0            False   en    NaN              2
# 1150                      NaN            False   en    NaN              0
# 1151               17557028.0            False   en    NaN              0
# 1152               53244424.0            False   pt    NaN              0
# 1153                      NaN            False   en    NaN              0
# 1154                      NaN            False   en    NaN              2
# 1155                      NaN            False   ja    NaN              0
# 1156                      NaN            False   en    NaN              0
# 1157                      NaN            False   en    NaN              0
# 1158                3962891.0            False   es    NaN              0
# 1159                      NaN            False   es    NaN              0
# 1160                6167072.0            False   en    NaN              2
# 1161                      NaN            False   en    NaN              2
# 1162               24693464.0            False   en    NaN              0
# 1163                 776031.0            False   en    NaN              1
#
#       retweeted                                             source  \
# 0         False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1         False  <a href="http://twitter.com" rel="nofollow">Tw...
# 2         False  <a href="http://twitter.com" rel="nofollow">Tw...
# 3         False  <a href="http://twitter.com" rel="nofollow">Tw...
# 4         False  <a href="http://twitter.com" rel="nofollow">Tw...
# 5         False  <a href="http://twitter.com" rel="nofollow">Tw...
# 6         False  <a href="http://twitter.com" rel="nofollow">Tw...
# 7         False  <a href="http://twitter.com" rel="nofollow">Tw...
# 8         False  <a href="http://twitter.com" rel="nofollow">Tw...
# 9         False  <a href="http://twitter.com" rel="nofollow">Tw...
# 10        False  <a href="http://twitter.com" rel="nofollow">Tw...
# 11        False  <a href="http://twitter.com" rel="nofollow">Tw...
# 12        False  <a href="http://twitter.com" rel="nofollow">Tw...
# 13        False  <a href="http://twitter.com" rel="nofollow">Tw...
# 14        False  <a href="http://twitter.com" rel="nofollow">Tw...
# 15        False  <a href="http://twitter.com" rel="nofollow">Tw...
# 16        False  <a href="http://twitter.com" rel="nofollow">Tw...
# 17        False  <a href="http://twitter.com" rel="nofollow">Tw...
# 18        False  <a href="http://twitter.com" rel="nofollow">Tw...
# 19        False  <a href="http://twitter.com" rel="nofollow">Tw...
# 20        False  <a href="http://twitter.com" rel="nofollow">Tw...
# 21        False  <a href="http://twitter.com" rel="nofollow">Tw...
# 22        False  <a href="http://twitter.com" rel="nofollow">Tw...
# 23        False  <a href="http://twitter.com" rel="nofollow">Tw...
# 24        False  <a href="http://twitter.com" rel="nofollow">Tw...
# 25        False  <a href="http://twitter.com" rel="nofollow">Tw...
# 26        False  <a href="http://twitter.com" rel="nofollow">Tw...
# 27        False  <a href="http://twitter.com" rel="nofollow">Tw...
# 28        False  <a href="http://twitter.com" rel="nofollow">Tw...
# 29        False  <a href="http://twitter.com" rel="nofollow">Tw...
# ...         ...                                                ...
# 1134      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1135      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1136      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1137      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1138      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1139      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1140      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1141      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1142      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1143      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1144      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1145      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1146      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1147      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1148      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1149      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1150      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1151      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1152      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1153      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1154      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1155      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1156      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1157      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1158      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1159      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1160      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1161      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1162      False  <a href="http://twitter.com" rel="nofollow">Tw...
# 1163      False  <a href="http://twitter.com" rel="nofollow">Tw...
#
#                                                    text  truncated  \
# 0     Votto leads off the 5th w/ his 10th homerun of...      False
# 1            @jamierumbelow or derived tables, but yes.      False
# 2                              iphone、ソフトバンクじゃん！知らなかったぁ      False
# 3     @NobleRot I think there's a company in Olathe ...      False
# 4     **MAYA ANGELO** has been deleted. Page is list...      False
# 5     Eat Sleep Draw!: www.ashleystuartgoodwin.com\n...      False
# 6                                       ふぇー。疲れたー。会社出ます。      False
# 7                                      Tea and then bed      False
# 8     10:56AM - The New Song We Sing by: Meredith An...      False
# 9     Reading 'Public Enemies' and doing laundry. Su...      False
# 10    Votto leads off the 5th w/ his 10th homerun of...      False
# 11                                           日本橋へ打ち合わせに      False
# 12                             iphone、ソフトバンクじゃん！知らなかったぁ      False
# 13    @NobleRot I think there's a company in Olathe ...      False
# 14             I'm "Adaptablity" today, how are you? :)      False
# 15    @kristyann Tell student who stood you up for m...      False
# 16    Перший Тернопільський "Снепшот" http://tr.im/kcrS      False
# 17    Votto leads off the 5th w/ his 10th homerun of...      False
# 18                                           日本橋へ打ち合わせに      False
# 19                      @srtalee y do dan la 2 al tiro!      False
# 20    @NobleRot I think there's a company in Olathe ...      False
# 21                                  Slleeeeeeeeepyyyyyy      False
# 22              @Sacc I left my wallet in El Segundo...      False
# 23             I'm "Adaptablity" today, how are you? :)      False
# 24    Перший Тернопільський "Снепшот" http://tr.im/kcrS      False
# 25                @Coverville I'd love to conduct that.      False
# 26                             @kajeaw ที่ไหนอะคับ มือ2      False
# 27                                           流れて来たな[mb]      False
# 28    Votto leads off the 5th w/ his 10th homerun of...      False
# 29                      @srtalee y do dan la 2 al tiro!      False
# ...                                                 ...        ...
# 1134                                         流れて来たな[mb]      False
# 1135                     一勝一敗　きもちよく勝ったのできっと明日はいい日と信じてねる      False
# 1136  Votto leads off the 5th w/ his 10th homerun of...      False
# 1137  Gold has not gone up consistently,that's anoth...      False
# 1138  Formula 1: al borde del colapso http://bit.ly/...      False
# 1139  @NobleRot I think there's a company in Olathe ...      False
# 1140  @smallbit apparently, they never hired any net...      False
# 1141           I'm "Adaptablity" today, how are you? :)      False
# 1142  "The sun rose slowly, as if it wasn't sure it ...      False
# 1143  @kristyann Tell student who stood you up for m...      False
# 1144  Перший Тернопільський "Снепшот" http://tr.im/kcrS      False
# 1145                           @kajeaw ที่ไหนอะคับ มือ2      False
# 1146  "The Shroud". The description in the pamphlet ...      False
# 1147  @laceyturnerhere http://twitpic.com/dzbak - He...      False
# 1148  Votto leads off the 5th w/ his 10th homerun of...      False
# 1149  @NobleRot I think there's a company in Olathe ...      False
# 1150  {9:21} And the breasts and the right shoulder ...      False
# 1151  @smallbit apparently, they never hired any net...      False
# 1152                   @FelpsVita acho chic! bem vindo!      False
# 1153  Eat Sleep Draw!: www.ashleystuartgoodwin.com\n...      False
# 1154           I'm "Adaptablity" today, how are you? :)      False
# 1155  動画を見る時にそれを批判するような意見がでてくるのは、多くの人がマンセーする中でも当然のこと...      False
# 1156  "The Shroud". The description in the pamphlet ...      False
# 1157  Votto leads off the 5th w/ his 10th homerun of...      False
# 1158                    @srtalee y do dan la 2 al tiro!      False
# 1159  Formula 1: al borde del colapso http://bit.ly/...      False
# 1160  @NobleRot I think there's a company in Olathe ...      False
# 1161           I'm "Adaptablity" today, how are you? :)      False
# 1162  @NubianMonarch me Caps....hell no! I don't do ...      False
# 1163              @Coverville I'd love to conduct that.      False
#
#                                                    user
# 0     {'id': 23011995, 'id_str': '23011995', 'name':...
# 1     {'id': 19750873, 'id_str': '19750873', 'name':...
# 2     {'id': 9117962, 'id_str': '9117962', 'name': '...
# 3     {'id': 12285702, 'id_str': '12285702', 'name':...
# 4     {'id': 19996729, 'id_str': '19996729', 'name':...
# 5     {'id': 17403059, 'id_str': '17403059', 'name':...
# 6     {'id': 4827361, 'id_str': '4827361', 'name': '...
# 7     {'id': 7277932, 'id_str': '7277932', 'name': '...
# 8     {'id': 39762094, 'id_str': '39762094', 'name':...
# 9     {'id': 14572636, 'id_str': '14572636', 'name':...
# 10    {'id': 23011995, 'id_str': '23011995', 'name':...
# 11    {'id': 4133061, 'id_str': '4133061', 'name': '...
# 12    {'id': 9117962, 'id_str': '9117962', 'name': '...
# 13    {'id': 12285702, 'id_str': '12285702', 'name':...
# 14    {'id': 3540871, 'id_str': '3540871', 'name': '...
# 15    {'id': 13988462, 'id_str': '13988462', 'name':...
# 16    {'id': 9325422, 'id_str': '9325422', 'name': '...
# 17    {'id': 23011995, 'id_str': '23011995', 'name':...
# 18    {'id': 4133061, 'id_str': '4133061', 'name': '...
# 19    {'id': 11664832, 'id_str': '11664832', 'name':...
# 20    {'id': 12285702, 'id_str': '12285702', 'name':...
# 21    {'id': 16012309, 'id_str': '16012309', 'name':...
# 22    {'id': 6296472, 'id_str': '6296472', 'name': '...
# 23    {'id': 3540871, 'id_str': '3540871', 'name': '...
# 24    {'id': 9325422, 'id_str': '9325422', 'name': '...
# 25    {'id': 11373772, 'id_str': '11373772', 'name':...
# 26    {'id': 12967962, 'id_str': '12967962', 'name':...
# 27    {'id': 6359412, 'id_str': '6359412', 'name': '...
# 28    {'id': 23011995, 'id_str': '23011995', 'name':...
# 29    {'id': 11664832, 'id_str': '11664832', 'name':...
# ...                                                 ...
# 1134  {'id': 6359412, 'id_str': '6359412', 'name': '...
# 1135  {'id': 14793869, 'id_str': '14793869', 'name':...
# 1136  {'id': 23011995, 'id_str': '23011995', 'name':...
# 1137  {'id': 40413272, 'id_str': '40413272', 'name':...
# 1138  {'id': 44474340, 'id_str': '44474340', 'name':...
# 1139  {'id': 12285702, 'id_str': '12285702', 'name':...
# 1140  {'id': 15952958, 'id_str': '15952958', 'name':...
# 1141  {'id': 3540871, 'id_str': '3540871', 'name': '...
# 1142  {'id': 5819932, 'id_str': '5819932', 'name': '...
# 1143  {'id': 13988462, 'id_str': '13988462', 'name':...
# 1144  {'id': 9325422, 'id_str': '9325422', 'name': '...
# 1145  {'id': 12967962, 'id_str': '12967962', 'name':...
# 1146  {'id': 40108440, 'id_str': '40108440', 'name':...
# 1147  {'id': 59756270, 'id_str': '59756270', 'name':...
# 1148  {'id': 23011995, 'id_str': '23011995', 'name':...
# 1149  {'id': 12285702, 'id_str': '12285702', 'name':...
# 1150  {'id': 23595193, 'id_str': '23595193', 'name':...
# 1151  {'id': 15952958, 'id_str': '15952958', 'name':...
# 1152  {'id': 20987976, 'id_str': '20987976', 'name':...
# 1153  {'id': 17403059, 'id_str': '17403059', 'name':...
# 1154  {'id': 3540871, 'id_str': '3540871', 'name': '...
# 1155  {'id': 19917723, 'id_str': '19917723', 'name':...
# 1156  {'id': 40108440, 'id_str': '40108440', 'name':...
# 1157  {'id': 23011995, 'id_str': '23011995', 'name':...
# 1158  {'id': 11664832, 'id_str': '11664832', 'name':...
# 1159  {'id': 44474340, 'id_str': '44474340', 'name':...
# 1160  {'id': 12285702, 'id_str': '12285702', 'name':...
# 1161  {'id': 3540871, 'id_str': '3540871', 'name': '...
# 1162  {'id': 21594697, 'id_str': '21594697', 'name':...
# 1163  {'id': 11373772, 'id_str': '11373772', 'name':...
#
# [1164 rows x 23 columns]

# %%
result = pd.concat([percentile_list, percentile_list1], axis=1)
result = result.drop_duplicates(subset='ids', keep="first") #dropping the same texts


result
# Out:
#                                                    texts                 ids
# 0      Euro Parliament votes overwhelmingly to reject...  220473289259233285
# 1      US have one currency, one Central Bank and one...  353060776707235841
# 2      More jobs for young people is my top priority ...  467647542378123264
# 3      Vote #Labour, get Tory. Vote Tory, get Labour....  471694322472353793
# 5      Answering my question in ECR Group J-C Juncker...  486509184708792320
# 6      Robert Halfon raising issue of illegal travell...  500600838419935232
# 7      Ignore the Labour lies, this is where #UKIP st...  512257283087429632
# 8      Next week I'll be grilling EU Commissioner can...  515077347645870080
# 9      #Migration can be positive for the UK - only i...  516923314225553409
# 10     "Vote UKIP, get Labour" says Dave. Really...? ...  517285141371453440
# 11     good presentation of Jonathan Hill, ready to t...  517317510719614976
# 12     Hungary is a shining model for other countries...  517374434278404096
# 13     Steven Woolfe's magisterial question to Lord H...  517562642723274752
# 14     #EPhearings2014 @BienkowskaEU 'lets put Europe...  517645289407401984
# 15     Bienkowska fluffed a simple question from @Ash...  517654781733928960
# 16     #Bienkowska committed to fast and fully enforc...  517661138319052801
# 17     Decision on Moscovici postponed #EPHearing2014...  517667224237400064
# 19     Our @TheresaMEP asks #Bienkowska what she'll d...  517673569724424192
# 20     #Bienkowska: Trademark reform must be handled ...  517676555456499714
# 21     #EU #budget: Member States need to stand by th...  517677345428492288
# 22     My summary for #Bienkowska: competent. #EPhear...  517679694544904192
# 23     Disappointed @BienkowskaEU didn't answer my qu...  517685087941701633
# 24     According to the papers I can eat a Bacon sarn...  517692033096773632
# 26     #Vestager: in particular markets like #energy ...  517709806271201282
# 27     Concrete example @AnnelieseDodds @vestager on ...  517719797652807681
# 28     Letter I sent today with @MarietjeSchaake dema...  517723618999283713
# 29     .@AnaGomesMEP and I sent this letter on @NABEE...  517724307892764672
# 30     As EP does not provide coffee in meetings Comm...  517735072754302976
# 31     #Vestager star Commissioner on key portfolio #...  517749884003561472
# 32     Great day supporting @JohnBickleyUKIP  with @N...  517768704424423426
# ...                                                  ...                 ...
# 12893  The so-called #LabourLeave fringe group opposi...  690304138282962944
# 12894  Hi @themichaelcaine I'm a huge fan and not a f...  690467753187217408
# 12895  I welcome @themichaelcaine's support for #Brex...  690468812165095424
# 12896  Great piece from @MaryCreaghMP on EU membershi...  690492167752695808
# 12897  On @BBCWorldatOne on the #migration crisis, Va...  690503602310373377
# 12898  #EUreferendum is going to be about working peo...  690514426991120384
# 12899  We have to be at table to deal with #TTIP: EU ...  690530471609044992
# 12900  There is a buzz &amp; excitement in the air fo...  690536033281298432
# 12901  #MichaelCaine said this am that bureaucrats in...  690542168285515776
# 12902  Who says #auditing and #politics cannot be fun...  690562265880330246
# 12903  Another packed hse in Limerick  for the launch...  690640099483197440
# 12904  Fantastic @EFDgroup public meeting with @JSeym...  690837121133907969
# 12905  @brianhayesMEP @EPPGroup @FineGael Will your c...  690847720706281473
# 12906  https://t.co/Zl9U7K5ABB good article from my c...  690847823764525056
# 12907  Memo to Tories for Reform in EU: Never mind th...  690861330555887616
# 12908  Great to be out meeting people in Wellingborou...  690861414945308672
# 12909  Tremendous enthusiasm out there to Leave the E...  690864079863414784
# 12911  My colleague @NirjDeva makes a highly valid po...  690908976251301888
# 12912  Proud to sign @Grassroots_Out's Kettering Decl...  690928472223563777
# 12915  Amazing support in Kettering for @Grassroots_O...  690932307583221761
# 12916  @UKIP West Mids. conference - 20th Feb, Wolver...  690947154362417152
# 12917  Signal that the Dublin Convention is now over ...  691005466818772993
# 12919  How long can the Calais scandal go on? - Jerem...  691007348148703233
# 12920  Yesterday's @Grassroots_Out event important fo...  691220570525032448
# 12921  I look forward to working with @LiamFoxMP, @Ka...  691221052521848833
# 12924  Time to lock EU leaders in a room to sort #ref...  691227199647662080
# 12926  Drastic drop in positive EU perception in Pola...  691248438504210432
# 12927  I'm with @UKYP North West now in Knowsley - gr...  691260217288454144
# 12928  Listening to some fab ideas from young people ...  691262296396599296
# 12930  First, big banks, now big pharma. In whose int...  691369745531158528
#
# [10125 rows x 2 columns]

# %%
newresult = pd.merge(dfnew, result, left_on = 'origTweetId', right_on = 'ids') 


df1 = newresult[['origUserId','origMepGroupShort']]
df1 = df1.groupby('origMepGroupShort').count().reset_index()
finaldf = pd.merge(newresult, df1, on ='origMepGroupShort')
finaldf = finaldf.loc[finaldf['origUserId_y'] >50]

finaldf['texts']=finaldf['texts'].str.replace('https?://(?:[-\w.]|(?:%[\da-fA-F]{2}))+',' ') #removing urls from texts using regex
finaldf.head(5)
# Out:
#    origUserId_x origUserScreenName  origMepId      origMepName  \
# 0      19017675       Nigel_Farage       4525     Nigel FARAGE
# 1     744743599           Tim_Aker      99650         Tim AKER
# 2     744743599           Tim_Aker      99650         Tim AKER
# 3     158021529          oflynnmep     124940  Patrick O'FLYNN
# 4     744743599           Tim_Aker      99650         Tim AKER
#
#    origMepGroupId origMepGroupShort  origMepCountryId origMepCountryShort  \
# 0               6              EFDD                27                 GBR
# 1               6              EFDD                27                 GBR
# 2               6              EFDD                27                 GBR
# 3               6              EFDD                27                 GBR
# 4               6              EFDD                27                 GBR
#
#    retweetUserId retweetUserScreenName  retweetMepId retweetMepName  \
# 0      121171051        MargotLJParker        124945  Margot PARKER
# 1      121171051        MargotLJParker        124945  Margot PARKER
# 2       19017675          Nigel_Farage          4525   Nigel FARAGE
# 3      108882900        RogerHelmerMEP          4516   Roger HELMER
# 4      952267464        JamesJimCarver        124971   James CARVER
#
#    retweetMepGroupId retweetMepGroupShort  retweetMepCountryId  \
# 0                  6                 EFDD                   27
# 1                  6                 EFDD                   27
# 2                  6                 EFDD                   27
# 3                  6                 EFDD                   27
# 4                  6                 EFDD                   27
#
#   retweetMepCountryShort                   origCreatedAt         origTweetId  \
# 0                    GBR  Wed Jul 04 11:05:03 +0000 2012  220473289259233285
# 1                    GBR  Wed May 28 16:47:44 +0000 2014  471694322472353793
# 2                    GBR  Wed May 28 16:47:44 +0000 2014  471694322472353793
# 3                    GBR  Sat Aug 16 11:11:55 +0000 2014  500600838419935232
# 4                    GBR  Wed Sep 17 15:10:28 +0000 2014  512257283087429632
#
#                  retweetCreatedAt      retweetTweetId lang  \
# 0  Sun Dec 07 21:46:00 +0000 2014  541710240014942209   en
# 1  Thu Dec 04 22:21:10 +0000 2014  540631925145493504   en
# 2  Sun Mar 29 18:53:32 +0000 2015  582254277122473984   en
# 3  Mon Nov 23 10:08:57 +0000 2015  668732964516294656   en
# 4  Wed Dec 17 23:05:07 +0000 2014  545354031577980928   en
#
#                                                texts                 ids  \
# 0  Euro Parliament votes overwhelmingly to reject...  220473289259233285
# 1  Vote #Labour, get Tory. Vote Tory, get Labour....  471694322472353793
# 2  Vote #Labour, get Tory. Vote Tory, get Labour....  471694322472353793
# 3  Robert Halfon raising issue of illegal travell...  500600838419935232
# 4  Ignore the Labour lies, this is where #UKIP st...  512257283087429632
#
#    origUserId_y
# 0          3261
# 1          3261
# 2          3261
# 3          3261
# 4          3261

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(strip_accents='unicode',min_df=10, max_df=0.50,stop_words='english')
vectorizer.fit(finaldf.texts)
X = vectorizer.fit_transform(finaldf.texts)
vectorizer
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=0.5, max_features=None, min_df=10,
#                 ngram_range=(1, 1), preprocessor=None, stop_words='english',
#                 strip_accents='unicode', token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans

kmeans = KMeans(random_state=0)
visualizer = KElbowVisualizer(kmeans)

visualizer.fit(X)
visualizer.show()

# %%
from yellowbrick.cluster import SilhouetteVisualizer

plt.figure(figsize=(2 * 5,  10 * 4))

scores = {}
for n_clusters in range(2, 20):
    plt.subplot(10, 2, n_clusters - 1)
    kmeans = KMeans(n_clusters, random_state=42)
    visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick')
    visualizer.fit(X)
    scores[n_clusters] = visualizer.silhouette_score_
    plt.title(f'clusters: {n_clusters} score: {visualizer.silhouette_score_}')

# %%
sorted(scores.items(), key=lambda kv: kv[1], reverse=True)
# Out:
# [(2, 0.04920016225044949),
#  (3, 0.043447690244157865),
#  (4, 0.03756635201408192),
#  (11, 0.0324079676268082),
#  (8, 0.030318148348607597),
#  (6, 0.02847622528483676),
#  (9, 0.0283227076991214),
#  (16, 0.028277597517311587),
#  (7, 0.026966289504038912),
#  (14, 0.02662461202453419),
#  (12, 0.025409087823715124),
#  (18, 0.024753751406707655),
#  (13, 0.024483090857975596),
#  (17, 0.024185183382459396),
#  (15, 0.023595860754019937),
#  (5, 0.02268147193671469),
#  (19, 0.020607076400859372),
#  (10, 0.01168871338864398)]

# %%
kmeans = KMeans(n_clusters=7, random_state=0).fit(X)

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

from yellowbrick.cluster import InterclusterDistance



# Instantiate the clustering model and visualizer
model = KMeans(3)
visualizer = InterclusterDistance(model)

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
model = KMeans(6)
visualizer = InterclusterDistance(model)

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
import numpy 
words=20
numpy.set_printoptions(threshold=1000)
clustercenters=kmeans.cluster_centers_.argsort()[:,::-1]
tf_feature_names=vectorizer.get_feature_names()
for i in range(0,7):
    print('Cluster %d:'%i)
    print()
    for y in clustercenters[i,:words]:
        print('%s'%tf_feature_names[y])
    print()
    
#the 0 cluster talks about workers union and migration
#the 1 cluster talks about european parliament
#the 2 cluster talks about the progressives
#the 3 cluster talks about labour rights
#the 4 cluster talks about uk labour party
#the 5 cluster talks about Cameron
#the 6 cluster talks about europe
# Out:
# Cluster 0:
#
# europe
# amp
# eppgroup
# eu
# people
# need
# change
# greece
# refugees
# migration
# work
# needs
# says
# future
# european
# new
# want
# good
# union
# juncker
#
# Cluster 1:
#
# today
# eu
# ukip
# great
# vote
# meps
# eppgroup
# day
# people
# european
# meeting
# debate
# parliament
# support
# ep
# ttip
# europarl_en
# join
# campaign
# party
#
# Cluster 2:
#
# great
# amp
# thanks
# eu
# eurolabour
# news
# speech
# support
# theprogressives
# european
# hear
# ep
# meeting
# eppgroup
# work
# labour
# campaign
# day
# meet
# team
#
# Cluster 3:
#
# amp
# eu
# eppgroup
# good
# meps
# today
# european
# meeting
# ttip
# uk
# ep
# vote
# need
# debate
# people
# theprogressives
# support
# greece
# labour
# rights
#
# Cluster 4:
#
# ukip
# vote
# labour
# party
# nhs
# uk
# people
# amp
# poll
# just
# immigration
# election
# policy
# lab
# voters
# meps
# national
# farage
# tories
# mep
#
# Cluster 5:
#
# eu
# uk
# leave
# referendum
# cameron
# meps
# people
# britain
# support
# need
# just
# european
# membership
# labour
# vote
# want
# migration
# turkey
# trade
# policy
#
# Cluster 6:
#
# european
# eppgroup
# ep
# ttip
# people
# vote
# parliament
# good
# meeting
# new
# just
# europarl_en
# meps
# debate
# support
# greece
# labour
# need
# theprogressives
# uk

# %%
#reading the files that i saved, so i dont have to wait every time
percentile_list=pd.read_pickle('Desktop/dummy.pkl')
percentile_list1=pd.read_pickle('Desktop/dummy1.pkl')

# %%
X = finaldf.texts
y = finaldf.origMepGroupShort
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)


from sklearn.feature_extraction.text import TfidfTransformer
transformer = TfidfTransformer()
transformer 

print(X_train)
# Out:
# 1145     UKIP membership has just gone over 44,000. Tod...
# 3207     'Renegotiation' a con job. EU fanatics hungrie...
# 8462     365 days have gone by &amp; Nadia Savchenko is...
# 4982     TTIP debate now underway in the EU parliament,...
# 10020    End of a successful @EPPGroup Bureau meeting i...
# 8940     #MH17 tragedy in 2014, might become a tragedy ...
# 852      Britain deserves better. Vote @UKIP.  /KUUF9yrxVR
# 1494     Lovely moment today in dudley when a couple ca...
# 9709     “European defense spending by country and subr...
# 6412     Huge congratulations to my good friend &amp; c...
# 2464     Heads Up: I'm on @BBC5Live @JPonpolitics at 10...
# 3635     Thanks to @BBCSurrey for having me on earlier ...
# 11236    .@EPPGroup calls for the immediate release of ...
# 1805     #UKIP believes firmly in the #NHS Not the Inte...
# 2288     Just 1 in 20 cars in Calais being checked for ...
# 7585     Is not a womens' issue. Men need to speak up t...
# 7080     @anthea_mcintyre @ddalton40 addressing the Eur...
# 9704     #LuxLeaks @ph_lamberts  apologised in CoP for ...
# 188      You say Ukip is a party for blokes? Time for a...
# 1123     The scale of net migration seen as the most im...
# 8866     I'll keep repeating it: If we want to prevent ...
# 11660    With @TerryReintke and @MollyMEP for photo wit...
# 7801     Starting now, debate on #Nigeria, live via  /Y...
# 8776     Here's the cross-party letter from 14 MEPs sen...
# 6391     The first thing we should do when we leave the...
# 10068    If I had to describe the #DigitalSingleMarket ...
# 1594     LISTEN: I discuss BBC bias on @LBC, here:  /86...
# 6678     Out campaigning with @CllrScottMann and some o...
# 7926     Today at #EPplenary with @petras_petras @ALDEg...
# 500      Here's why tomorrow will be Gordon Brown's eig...
#                                ...
# 8666     Spanish Government Plan to eliminate Catalan A...
# 11096    @Europarl_EN - exchange of views with Juncker:...
# 6396     My report on eu competition well received in E...
# 12309    I can't believe the official results in Turkey...
# 3385     Women deserve #EqualPayForEqualWork RT to remi...
# 4555     Change &amp; Future #Europe #Greece @giannipit...
# 1184     Imagine for a second that this was a UKIP coun...
# 6420     I voted against @JunckerEU and his Commission,...
# 5051     Labour MEPs show their support for #PeoplesPos...
# 5311     The TUC bill is a direct attempt to curtail pe...
# 2433     Lebanese government minister says Islamic Stat...
# 6949     Someone enters France illicitly, and travels f...
# 10583    Happy Kilcummim folk in Bruff   celebrating Ke...
# 769      £10bn on the war. £10m on the report. And stil...
# 1685     Hmm, not sure who to vote for?! Joke of course...
# 8322     A man of his word: Nigel Farage. He writes to ...
# 11111    #Turkey has key role to play in solving #refug...
# 11363     @TerryReintke ach nee, dieses wars?  /mQAJzeLkhn
# 11636    @HeidiHautala quotes #Nemtzow who said 2011 in...
# 5578     Lovely to talk Chopin with @rozathun this morn...
# 4426     Official signing of the Regulation on European...
# 466      Delighted by public support at today's officia...
# 6265     #LabourLeave launched today, but has next to n...
# 5734     At Press Conference with #Albania Prime Minist...
# 11284    Will be honoured to launch  ex-Taoiseach! John...
# 11964    Bloomberg quotes Finnish Finance Minister Alex...
# 5191     Childers calls on Fine Gael to support EU-wide...
# 5390     Internet 4 Social Good @YouTube @Google @Eu40 ...
# 860      Britain tops table for immigrants per head amo...
# 7270     Think-tank @europeanreform, linked to @Allianc...
# Name: texts, Length: 10325, dtype: object

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
text_clf1 = Pipeline([('vect', CountVectorizer(strip_accents='unicode',min_df=10, max_df=0.50,stop_words='english')),
                     ('tfidf', TfidfTransformer()),
                     ('clf', MultinomialNB()),
                    ])
text_clf1.fit(X_train, y_train)
predicted = text_clf1.predict(X_test)
np.mean(predicted == y_test) 
from sklearn import metrics

print(metrics.classification_report(y_test, predicted,
                                    target_names=finaldf.origMepGroupShort.drop_duplicates()))
print()
print(metrics.confusion_matrix(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#         EFDD       0.64      0.51      0.57       367
#          S&D       0.90      0.20      0.33       221
#          ECR       0.65      0.91      0.76       669
#         ALDE       0.64      0.70      0.67       409
#          EPP       0.93      0.19      0.31        70
#   Greens-EFA       0.74      0.36      0.48       219
#      GUE-NGL       0.61      0.73      0.66       627
#
#     accuracy                           0.65      2582
#    macro avg       0.73      0.51      0.54      2582
# weighted avg       0.67      0.65      0.62      2582
#
#
# [[186   1  54  48   1  11  66]
#  [ 10  44  90  27   0   2  48]
#  [  9   0 607   8   0   0  45]
#  [ 33   1  27 286   0   5  57]
#  [  5   0  18   2  13   2  30]
#  [ 25   2  39  30   0  79  44]
#  [ 22   1  96  45   0   8 455]]

# %%
from sklearn.linear_model import SGDClassifier
text_clf2 = Pipeline([('vect', CountVectorizer()),
                     ('tfidf', TfidfTransformer()),
                     ('clf', SGDClassifier(loss='hinge', penalty='l2',
                                           alpha=1e-3,
                                           random_state=42))
                    ])
text_clf2.fit(X_train, y_train)
predicted = text_clf2.predict(X_test)
np.mean(predicted == y_test)    
from sklearn import metrics

print(metrics.classification_report(y_test, predicted,
                                    target_names=finaldf.origMepGroupShort.drop_duplicates()))
print()
print(metrics.confusion_matrix(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#         EFDD       0.84      0.58      0.68       367
#          S&D       0.79      0.29      0.43       221
#          ECR       0.63      0.95      0.76       669
#         ALDE       0.72      0.76      0.74       409
#          EPP       0.88      0.40      0.55        70
#   Greens-EFA       0.72      0.45      0.55       219
#      GUE-NGL       0.70      0.72      0.71       627
#
#     accuracy                           0.70      2582
#    macro avg       0.75      0.59      0.63      2582
# weighted avg       0.72      0.70      0.68      2582
#
#
# [[213   3  63  32   1  11  44]
#  [  6  65  84  20   1   4  41]
#  [  2   4 635   5   0   1  22]
#  [ 11   2  36 311   0  12  37]
#  [  1   0  20   5  28   1  15]
#  [ 12   5  45  22   1  98  36]
#  [ 10   3 119  35   1  10 449]]

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'vect__ngram_range': [(1, 1), (1, 2)],
              'tfidf__use_idf': (True, False),
              'clf__alpha': (1e-2, 1e-3)
             }
gs_clf = GridSearchCV(text_clf, parameters, n_jobs=-1, cv=5)
gs_clf = gs_clf.fit(X_train, y_train)

predicted = gs_clf.predict(X_test)
np.mean(predicted == y_test) 
print(metrics.classification_report(y_test, predicted,
                                    target_names=finaldf.origMepGroupShort.drop_duplicates()))
print()
print(metrics.confusion_matrix(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#         EFDD       0.79      0.63      0.70       367
#          S&D       0.87      0.29      0.44       221
#          ECR       0.64      0.96      0.77       669
#         ALDE       0.73      0.76      0.75       409
#          EPP       0.91      0.43      0.58        70
#   Greens-EFA       0.82      0.51      0.63       219
#      GUE-NGL       0.75      0.74      0.74       627
#
#     accuracy                           0.72      2582
#    macro avg       0.79      0.62      0.66      2582
# weighted avg       0.75      0.72      0.71      2582
#
#
# [[233   2  59  35   1   5  32]
#  [ 10  65  92  18   1   3  32]
#  [  1   4 642   3   0   1  18]
#  [ 19   1  38 311   0   6  34]
#  [  2   0  20   5  30   1  12]
#  [ 16   2  39  20   0 112  30]
#  [ 13   1 109  32   1   8 463]]

# %%
import numpy as np
from sklearn.dummy import DummyClassifier
dummy_clf = DummyClassifier(strategy="most_frequent")
dummy_clf.fit(X_train, y_train)
DummyClassifier(strategy='most_frequent')
dummy_clf.predict(X_test)
dummy_clf.score(X_test, y_test)
# Out:
# 0.25910147172734316

# %%
predicted = text_clf1.predict(X_test)
np.mean(predicted == y_test)
# Out:
# 0.6467854376452362

# %%
predicted = text_clf2.predict(X_test)
np.mean(predicted == y_test)
# Out:
# 0.6967467079783114

# %%
predicted = gs_clf.predict(X_test)
np.mean(predicted == y_test) 
#All 3 algorithms seem to predict better than the dummy classifier
#The best classifier is with the grid search algorithm
#All classifiers cannot predict well tweets from EPP party because we have a few tweets from this party
# Out:
# 0.7188226181254841
